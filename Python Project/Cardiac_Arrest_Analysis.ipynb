# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv('heart_attack_prediction_dataset.csv')

# Print the Data
print(df)
# Out:
#      Patient ID  Age  Gender  Cholesterol Blood Pressure  Heart Rate  \
# 0       BMW7812   67    Male          208         158/88          72
# 1       CZE1114   21    Male          389         165/93          98
# 2       BNI9906   21  Female          324         174/99          72
# 3       JLN3497   84    Male          383        163/100          73
# 4       GFO8847   66    Male          318          91/88          93
# ...         ...  ...     ...          ...            ...         ...
# 8758    MSV9918   60    Male          121          94/76          61
# 8759    QSV6764   28  Female          120        157/102          73
# 8760    XKA5925   47    Male          250         161/75         105
# 8761    EPE6801   36    Male          178         119/67          60
# 8762    ZWN9666   25  Female          356         138/67          75
#
#       Diabetes  Family History  Smoking  Obesity  ...  \
# 0            0               0        1        0  ...
# ...

# %%
# Print first 5 rows
df.head()
# Out:
#   Patient ID  Age  Gender  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    BMW7812   67    Male          208         158/88          72         0
# 1    CZE1114   21    Male          389         165/93          98         1
# 2    BNI9906   21  Female          324         174/99          72         1
# 3    JLN3497   84    Male          383        163/100          73         1
# 4    GFO8847   66    Male          318          91/88          93         1
#
#    Family History  Smoking  Obesity  ...  Sedentary Hours Per Day  Income  \
# 0               0        1        0  ...                 6.615001  261404
# 1               1        1        1  ...                 4.963459  285768
# 2               0        0        0  ...                 9.463426  235282
# 3               1        1        0  ...                 7.648981  125640
# 4               1        1        1  ...                 1.514821  160555
#
#          BMI  Triglycerides  Physical Activity Days Per Week  \
# ...

# %%
# Print last 5 rows
df.tail()
# Out:
#      Patient ID  Age  Gender  Cholesterol Blood Pressure  Heart Rate  \
# 8758    MSV9918   60    Male          121          94/76          61
# 8759    QSV6764   28  Female          120        157/102          73
# 8760    XKA5925   47    Male          250         161/75         105
# 8761    EPE6801   36    Male          178         119/67          60
# 8762    ZWN9666   25  Female          356         138/67          75
#
#       Diabetes  Family History  Smoking  Obesity  ...  \
# 8758         1               1        1        0  ...
# 8759         1               0        0        1  ...
# 8760         0               1        1        1  ...
# 8761         1               0        1        0  ...
# 8762         1               1        0        0  ...
#
#       Sedentary Hours Per Day  Income        BMI  Triglycerides  \
# 8758                10.806373  235420  19.655895             67
# 8759                 3.833038  217881  23.993866            617
# ...

# %%
# Print the summary of the DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Patient ID                       8763 non-null   object
#  1   Age                              8763 non-null   int64
#  2   Gender                           8763 non-null   object
#  3   Cholesterol                      8763 non-null   int64
#  4   Blood Pressure                   8763 non-null   object
#  5   Heart Rate                       8763 non-null   int64
#  6   Diabetes                         8763 non-null   int64
#  7   Family History                   8763 non-null   int64
#  8   Smoking                          8763 non-null   int64
#  9   Obesity                          8763 non-null   int64
#  10  Alcohol Consumption              8763 non-null   int64
#  11  Exercise Hours Per Week          8763 non-null   float64
# ...

# %%
# To know the total number of rows and columns in the DataFrame
df.shape
# Out:
# (8763, 26)

# %%
# Shows basic statistics (like mean, min, max) for each numerical column in the DataFrame
df.describe()
# Out:
#                Age  Cholesterol   Heart Rate     Diabetes  Family History  \
# count  8763.000000  8763.000000  8763.000000  8763.000000     8763.000000
# mean     53.707977   259.877211    75.021682     0.652288        0.492982
# std      21.249509    80.863276    20.550948     0.476271        0.499979
# min      18.000000   120.000000    40.000000     0.000000        0.000000
# 25%      35.000000   192.000000    57.000000     0.000000        0.000000
# 50%      54.000000   259.000000    75.000000     1.000000        0.000000
# 75%      72.000000   330.000000    93.000000     1.000000        1.000000
# max      90.000000   400.000000   110.000000     1.000000        1.000000
#
#            Smoking      Obesity  Alcohol Consumption  Exercise Hours Per Week  \
# count  8763.000000  8763.000000          8763.000000              8763.000000
# mean      0.896839     0.501426             0.598083                10.014284
# ...

# %%
# Counting all null values in the DataFrame
df.isnull().sum()
# Out:
# Patient ID                         0
# Age                                0
# Gender                             0
# Cholesterol                        0
# Blood Pressure                     0
# Heart Rate                         0
# Diabetes                           0
# Family History                     0
# Smoking                            0
# Obesity                            0
# Alcohol Consumption                0
# Exercise Hours Per Week            0
# Diet                               0
# Previous Heart Problems            0
# Medication Use                     0
# Stress Level                       0
# Sedentary Hours Per Day            0
# Income                             0
# BMI                                0
# Triglycerides                      0
# Physical Activity Days Per Week    0
# Sleep Hours Per Day                0
# Country                            0
# Continent                          0
# Hemisphere                         0
# ...

# %%
# Fetching Unique Values from the DataFrame
df.nunique()
# Out:
# Patient ID                         8763
# Age                                  73
# Gender                                2
# Cholesterol                         281
# Blood Pressure                     3915
# Heart Rate                           71
# Diabetes                              2
# Family History                        2
# Smoking                               2
# Obesity                               2
# Alcohol Consumption                   2
# Exercise Hours Per Week            8763
# Diet                                  3
# Previous Heart Problems               2
# Medication Use                        2
# Stress Level                         10
# Sedentary Hours Per Day            8763
# Income                             8615
# BMI                                8763
# Triglycerides                       771
# Physical Activity Days Per Week       8
# Sleep Hours Per Day                   7
# Country                              20
# ...

# %% [markdown]
# # ***Exploratory Data Analysis***

# %%
# Set the figure size
plt.figure(figsize=(15, 6))
# Define a color palette for the bars
colors = ["#003366", "#99c2ff"]
# Create a bar plot
sns.barplot(data=df, x='Country', y='Age', hue='Gender', errorbar=None, palette=colors)
# Set the title
plt.title("Age Distribution By Country & Gender")
# Label the x-axis
plt.xlabel("Country")
# Label the y-axis
plt.ylabel("Age")
# Rotate the x-axis labels
plt.xticks(rotation=45)
# Display the plot
plt.show()

# %%
# Count the number of patients in each continent
continent_counts = df['Continent'].value_counts()
# Set the size of the figure
plt.figure(figsize=(10, 6))
# Define a color palette for the pie chart segments
colors = ["#99c2ff", "#66a3ff", "#3385ff", "#0066ff", "#0052cc", "#004099", "#cce0ff", "#e6f2ff"]
# Create a pie chart
plt.pie(continent_counts, labels=continent_counts.index, autopct='%1.1f%%', startangle=140, colors=colors)
# Set the title
plt.title('Patient Distribution By Continent')
# Ensure the pie chart is circular by setting equal aspect ratio
plt.axis('equal')
# Display the plot
plt.show()

# %%
# Create a pivot table to summarize blood pressure counts by continent and country
pivot_table = df.pivot_table(index='Continent', columns='Country', values='Blood Pressure', aggfunc='count')
# Set the figure size
plt.figure(figsize=(15, 6))
# Create a heatmap
sns.heatmap(pivot_table, annot=True, cmap='coolwarm', fmt='g')
# Set the title
plt.title("Blood Pressure Count By Countries & Continent")
# Label the x-axis
plt.xlabel("Country")
# Label the y-axis
plt.ylabel("Continent")
# Display the plot
plt.show()

# %%
# Set the figure size
plt.figure(figsize=(12, 6))
# Create a histogram
sns.histplot(data=df, x="Cholesterol", bins=20, kde=True, color="#66a3ff")
# Set the title
plt.title("Cholesterol Distribution")
# Label the x-axis
plt.xlabel("Cholesterol (mg/dL)")
# Label the y-axis
plt.ylabel("Frequency")
# Display the plot
plt.show()

# %%
# Set the figure size
plt.figure(figsize=(18, 6))
# Create a line plot
sns.lineplot(data=df, x="Country", y="Exercise Hours Per Week", marker="o", color="#003366")
# Set the title
plt.title("Exercise Hours Per Week By Country")
# Rotate the x-axis labels
plt.xticks(rotation=45)
# Display the plot
plt.show()

# %%
# Set the figure size
plt.figure(figsize=(12, 6))
# Define a color palette for the donut chart
color = ["#66a3ff", "#0066ff", "#004099"]
# Count the occurrences of each diet type in the dataset
diet_counts = df["Diet"].value_counts()
# Create a donut chart
plt.pie(diet_counts, labels=diet_counts.index, autopct="%1.1f%%", colors=color, wedgeprops={"width": 0.4})
# Set the title
plt.title("Diet Distribution")
# Display the chart
plt.show()

# %%
# Set the figure size
plt.figure(figsize=(18, 6))
# Create a line plot
sns.lineplot(data=df, x="Age", y="Heart Rate", marker="o", color="#00224d")
# Set the title
plt.title("Heart Rate By Age")
# Rotate the x-axis labels
plt.xticks(rotation=45)
# Display the plot
plt.show()

# %%
# Set the figure size
plt.figure(figsize=(10, 6))
# Create a bar plot
sns.countplot(data=df, x='Alcohol Consumption', hue='Continent', palette="Blues")
# Set the title
plt.title('Alcohol Consumption By Continent')
# Label the x-axis
plt.xlabel("Alocohol Consumption")
# Label the y-axis
plt.ylabel("Count")
# Display the plot
plt.show()

# %%
# Create a pivot table to summarize BMI  by continent and country
pivot_table = df.pivot_table(index='Continent', columns='Country', values='BMI', aggfunc='mean')
# Set the figure size
plt.figure(figsize=(15, 6))
# Create a heatmap
sns.heatmap(pivot_table, annot=True, cmap='coolwarm', fmt='.1f')
# Set the title
plt.title("Average BMI By Continent & Country")
# Label the x-axis
plt.xlabel("Country")
# Label the y-axis
plt.ylabel("Continent")
# Display the plot
plt.show()

# %%
# Set the figure size
plt.figure(figsize=(12, 6))
# Create a histogram
sns.histplot(data=df, x='Age', hue='Smoking', multiple='stack', bins=10, palette='Blues')
# Set the title
plt.title('Age Distribution By Smoking Status')
# Display the plot
plt.show()

# %%
# Count the occurrences of each smoking status in the dataset
smoking_counts = df['Obesity'].value_counts()
# Define a color palette for the donut chart
color = ["#0066ff", "#004099"]
# Set the figure size
plt.figure(figsize=(8, 6))
# Create a donut chart
plt.pie(smoking_counts, labels=smoking_counts.index, colors=color, autopct='%1.1f%%', startangle=90,wedgeprops=dict(width=0.4))
# Set the title
plt.title('Obesity Status Distribution')
# Display the chart
plt.show()

# %%
# Set the figure size
plt.figure(figsize=(18, 6))
# Group the data by year and calculate the average exercise hours
average_exercise = df.groupby('Country')['Heart Attack Risk'].mean().reset_index()
# Create an area plot to visualize the trend of average exercise hours over the years
sns.lineplot(data=average_exercise, x='Country', y='Heart Attack Risk', marker='o', color='blue')
plt.fill_between(average_exercise['Country'], average_exercise['Heart Attack Risk'], color='blue', alpha=0.3)
# Set the title
plt.title('Average Heart Attack Risk By Countries')
# Label the x-axis
plt.xlabel('Country')
# Label the y-axis
plt.ylabel('Average Heart Attack Risk')
# Rotate the x-axis labels
plt.xticks(rotation=45)
# Display the plot
plt.show()

# %%
# Group the data by Country and calculate the mean stress level for each country
country_stress = df.groupby('Country')['Stress Level'].mean().reset_index()
# Set the figure size
plt.figure(figsize=(15, 6))
# Create a line plot
sns.lineplot(data=country_stress, x="Country", y="Stress Level", marker="o", color="#00224d")
# Set the title
plt.title("Stress Level By Country")
# Rotate the x-axis labels
plt.xticks(rotation=45)
# Display the plot
plt.show()

# %% [markdown]
# # **Conclusion:- The analysis highlights key factors influencing heart health, including age, cholesterol levels, and lifestyle habits. Patients range from 18 to 90 years, with an average cholesterol level of 260 mg/dL. Lifestyle disparities, such as variations in physical activity, sedentary hours, and BMI, significantly impact heart attack risk, which is elevated in 36% of cases. These findings emphasize the importance of balanced habits and proactive health measures to mitigate cardiovascular risks.**
